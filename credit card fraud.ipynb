# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("D:\Internship\Project 4\credit card fraud.ipynb", encoding='latin1')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.758702e-12 -8.252296e-13 -9.637438e-13  8.316234e-13
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.592013e-13  4.247308e-13 -3.050183e-13  8.692882e-14 -1.179710e-12
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1081

# %%
df = df.drop_duplicates( keep='first')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 283726 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    283726 non-null  float64
#  1   V1      283726 non-null  float64
#  2   V2      283726 non-null  float64
#  3   V3      283726 non-null  float64
#  4   V4      283726 non-null  float64
#  5   V5      283726 non-null  float64
#  6   V6      283726 non-null  float64
#  7   V7      283726 non-null  float64
#  8   V8      283726 non-null  float64
#  9   V9      283726 non-null  float64
#  10  V10     283726 non-null  float64
#  11  V11     283726 non-null  float64
#  12  V12     283726 non-null  float64
#  13  V13     283726 non-null  float64
#  14  V14     283726 non-null  float64
#  15  V15     283726 non-null  float64
#  16  V16     283726 non-null  float64
#  17  V17     283726 non-null  float64
#  18  V18     283726 non-null  float64
#  19  V19     283726 non-null  float64
# ...

# %%
# disreibution of legit transection and fradulent transection
df['Class'].value_counts()
# Out:
# 0    283253
# 1       473
# Name: Class, dtype: int64

# %%
#this data set is higly unbalanced
#0 represents legit trans
#1 represents fraud trans

# %%
legit =df[df.Class == 0]
fraud =df[df.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (283253, 31)
# (473, 31)

# %%
legit.Amount.describe()
# Out:
# count    283253.000000
# mean         88.413575
# std         250.379023
# min           0.000000
# 25%           5.670000
# 50%          22.000000
# 75%          77.460000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     473.000000
# mean      123.871860
# std       260.211041
# min         0.000000
# 25%         1.000000
# 50%         9.820000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
#Compares the values for both trans
df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94835.058093  0.013439 -0.009829  0.012853 -0.010440  0.006769
# 1      80450.513742 -4.498280  3.405965 -6.729599  4.472591 -2.957197
#
#              V6        V7        V8        V9  ...       V20      V21  \
# Class                                          ...
# 0      0.001251  0.010447 -0.002448  0.002613  ... -0.000489 -0.00115
# 1     -1.432518 -5.175912  0.953255 -2.522124  ...  0.405043  0.46655
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000160  0.000360  0.000393 -0.000301  0.000065  0.001409  0.000418
# 1      0.086639 -0.096464 -0.106643  0.040615  0.050456  0.213774  0.078270
#
#            Amount
# Class
# 0       88.413575
# 1      123.871860
#
# [2 rows x 30 columns]

# %%
#under sampling

# %%
legit_sample = legit.sample(n=492)

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.describe()
# Out:
#                 Time          V1          V2          V3          V4  \
# count     965.000000  965.000000  965.000000  965.000000  965.000000
# mean    86327.594819   -2.210519    1.654311   -3.282320    2.241779
# std     48567.208746    5.344714    3.519368    6.012055    3.135832
# min        59.000000  -30.552380   -8.995586  -31.103685   -3.555067
# 25%     43643.000000   -2.729482   -0.166146   -4.875397    0.010612
# 50%     77627.000000   -0.721137    0.905603   -1.195941    1.287839
# 75%    134256.000000    1.080433    2.684104    0.329075    4.100098
# max    172764.000000    2.368058   22.057729    3.121217   12.114672
#
#                V5          V6          V7          V8          V9  ...  \
# count  965.000000  965.000000  965.000000  965.000000  965.000000  ...
# mean    -1.445549   -0.708744   -2.556338    0.496863   -1.200577  ...
# std      4.106606    1.687703    5.495447    4.030410    2.292117  ...
# ...

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 147027   88045.0  2.155044 -0.147191 -2.200839 -1.538507  0.260083 -2.080166
# 73979    55373.0  1.236809 -1.551907  0.036274 -1.222784  0.458597  4.519633
# 212956  139056.0  1.753401 -0.540238 -0.996123  0.459716 -0.107665 -0.180388
# 110318   71768.0  1.145728  0.111937  0.576952  0.511904 -0.369142 -0.319302
# 19830    30585.0  1.259083 -0.061042 -1.586239 -0.615404  2.294742  3.017576
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 147027  0.788316 -0.712967  0.946952  ...  0.134024  0.643227 -0.044200
# 73979  -2.092671  1.235343  0.725153  ...  0.073644  0.351358 -0.184818
# 212956 -0.035266 -0.086190  0.314813  ...  0.100623  0.147444  0.127656
# 110318 -0.125315  0.082239 -0.187698  ... -0.163793 -0.508386  0.176040
# 19830  -0.106586  0.668462 -0.316571  ... -0.412725 -1.472489  0.075689
#
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# 0    492
# 1    473
# Name: Class, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      91977.715447 -0.011107 -0.029698  0.031833  0.097116  0.007723
# 1      80450.513742 -4.498280  3.405965 -6.729599  4.472591 -2.957197
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.012921 -0.037927  0.058097  0.069934  ...  0.017611 -0.000462
# 1     -1.432518 -5.175912  0.953255 -2.522124  ...  0.405043  0.466550
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.002147  0.019704  0.018430 -0.002652 -0.000151 -0.008221 -0.003752
# 1      0.086639 -0.096464 -0.106643  0.040615  0.050456  0.213774  0.078270
#
#            Amount
# Class
# 0       87.103659
# 1      123.871860
#
# [2 rows x 30 columns]

# %%
X1= new_dataset.drop(columns='Class', axis=1)

# %%
print(X1)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 147027   88045.0  2.155044 -0.147191 -2.200839 -1.538507  0.260083 -2.080166
# 73979    55373.0  1.236809 -1.551907  0.036274 -1.222784  0.458597  4.519633
# 212956  139056.0  1.753401 -0.540238 -0.996123  0.459716 -0.107665 -0.180388
# 110318   71768.0  1.145728  0.111937  0.576952  0.511904 -0.369142 -0.319302
# 19830    30585.0  1.259083 -0.061042 -1.586239 -0.615404  2.294742  3.017576
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
y1 = new_dataset['Class']

# %%
print(y1)
# Out:
# 147027    0
# 73979     0
# 212956    0
# 110318    0
# 19830     0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 965, dtype: int64

# %%
# MODEL 1

# %%
X1_train,X1_test,y1_train,y1_test=train_test_split(X1,y1,test_size=0.3,random_state=123)

# %%
print(X1.shape,X1_train.shape , X1_test.shape)
# Out:
# (965, 30) (675, 30) (290, 30)

# %%
lr=LogisticRegression()

# %%
model2=lr.fit(X1_train,y1_train)

# %%
prediction2=model2.predict(X1_test)

# %%
accuracy_score(y1_test,prediction2)
# Out:
# 0.9413793103448276

# %%
# MODEL 2

# %%
from sklearn.model_selection import train_test_split

# %%
X2= new_dataset.drop(columns='Class', axis=1)

# %%
y2 = new_dataset['Class']

# %%
X2_train,X2_test,y2_train,y2_test=train_test_split(X2,y2,test_size=0.30,random_state=123)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier()

# %%
model=rfc.fit(X2_train,y2_train)

# %%
prediction=model.predict(X2_test)
http://localhost:8888/notebooks/credit%20card%20fraud.ipynb#

# %%
accuracy_score(y2_test,prediction)
# Out:
# 0.9517241379310345

# %%
# Both of the models is performing with good accuracy
